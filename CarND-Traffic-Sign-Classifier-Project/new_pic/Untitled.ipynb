# %%
# Load pickled data
import pickle
import numpy as np
import random
import math
import tensorflow as tf
from sklearn.utils import shuffle
from skimage import transform as tform
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import scipy

# %%
image1 = mpimg.imread('00597.ppm')
image2 = mpimg.imread('00618.ppm')
image3 = mpimg.imread('00713.ppm')
image4 = mpimg.imread('10102.ppm')
image5 = mpimg.imread('10187.ppm')

# %%
plt.imshow(image1)
image1.shape
image1_resize = scipy.misc.imresize(image1, (32,32,3));
plt.imshow(image1_resize)
image1_resize.shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(image2)
image2.shape
image2_resize = scipy.misc.imresize(image2, (32,32,3));
plt.imshow(image2_resize)
image2_resize.shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(image3)
image3.shape
image3_resize = scipy.misc.imresize(image3, (32,32,3));
plt.imshow(image3_resize)
image3_resize.shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(image4)
image4.shape
image4_resize = scipy.misc.imresize(image4, (32,32,3));
plt.imshow(image4_resize)
image4_resize.shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(image5)
image5.shape
image5_resize = scipy.misc.imresize(image5, (32,32,3));
plt.imshow(image5_resize)
image5_resize.shape
# Out:
# (32, 32, 3)
